# %% [markdown]
# # Example
# Example data set training with demonstration of visualizations:
#  - Text Visualization of Boundary Logic and Resulting Conditional Probability Distribution
#  - Graphical Visualization of 2D Classifier
#  - Graphical Visualization of 2D Classifier's Prediction Confidence

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from python.model.gosdt import GOSDT
from python.model.pygosdt import PyGOSDT
from python.model.osdt import OSDT
from python.model.visualizer import plot2DClassifier, plot2DConfidence

# dataframe = pd.DataFrame(pd.read_csv('experiments/preprocessed/compas-binary.csv'))
# dataframe = pd.DataFrame(pd.read_csv('experiments/datasets/compas/train.csv'))
# dataframe = pd.DataFrame(pd.read_csv('experiments/datasets/iris/original.csv'))
dataframe = pd.DataFrame(pd.read_csv('experiments/scalability/iris-setosa.csv'))

X = dataframe[dataframe.columns[0:2]]
y = dataframe[dataframe.columns[-1:]]

hyperparameters = {
    # "objective": "acc",
    "regularization": 0.01,
    "uncertainty_tolerance": 0.0,
    "output_limit": 1,
    "time_limit": 30000,

    "verbose": True,

    "optimism": 0.7,
    "equity": 0.5,
    "sample_depth": 1,

    "opencl_platform_index": -1,
    "opencl_device_index": -1
}

model = OSDT(hyperparameters, preprocessor="complete")
start = time.time()
model.fit(X, y)
finish = time.time()
print("Execution Time: {}".format(finish - start))

prediction = model.predict(X)
training_accuracy = model.score(X, y)
print("Training Accuracy: {}".format(training_accuracy))
print(model.tree)
plot2DClassifier("Visualizer", X, y, model)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-caa139c12ba7> in <module>
#       4 import time
#       5 from python.model.gosdt import GOSDT
# ----> 6 from python.model.pygosdt import PyGOSDT
#       7 from python.model.osdt import OSDT
#       8 from python.model.visualizer import plot2DClassifier, plot2DConfidence
#
# ~/Dropbox/NSS/gosdt/python/model/pygosdt.py in <module>
#       8
#       9 # local imports
# ---> 10 from .pygosdt_lib.models.parallel_osdt_classifier import ParallelOSDTClassifier
#      11 from .encoder import Encoder
#      12 from .tree_classifier import TreeClassifier
#
# ~/Dropbox/NSS/gosdt/python/model/pygosdt_lib/models/parallel_osdt_classifier.py in <module>
#       3
#       4 # local imports
# ----> 5 from model.pygosdt_lib.models.parallel_osdt import ParallelOSDT
#       6
#       7 # This is mainly a wrapper class which makes the model compliant with Sci-kit Learn's DecisionTreeClassifier interface
#
# ModuleNotFoundError: No module named 'model'

# %% [markdown]
# ### 2D Classifer Visualization

# %%
plot2DClassifier('GOSDT with TreeEncoding', X, y, model)

# %% [markdown]
# ### 2D Classifer Visualization (Confidence Levels)

# %%
for i, tree in enumerate(forest.trees):
    if i >= 10:
        print("Too many models produced, truncating visualization")
        break
    plot2DConfidence("Tree {} (Classification Confidence)".format(i), X, y, tree)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4ae49d5385af> in <module>
# ----> 1 for i, tree in enumerate(forest.trees):
#       2     if i >= 10:
#       3         print("Too many models produced, truncating visualization")
#       4         break
#       5     plot2DConfidence("Tree {} (Classification Confidence)".format(i), X, y, tree)
#
# NameError: name 'forest' is not defined
